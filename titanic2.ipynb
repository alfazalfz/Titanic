# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# LOADING DATA

# %%
train = pd.read_csv("/kaggle/input/titanic/train.csv")
test = pd.read_csv("/kaggle/input/titanic/test.csv")

# %%
test2 = pd.read_csv("/kaggle/input/titanic/test.csv")

# %%
train.head()

# %%
train["Sex"] = train["Sex"].astype('category')

# %%
train2 = train

# %%
train2["Sex"]=train.Sex.cat.codes

# %%
train["Embarked"] = train["Embarked"].astype('category')

# %%
train2["Embarked"]=train.Embarked.cat.codes

# %%
train.info()

# %% [markdown]
# Imputation for missing values

# %%
from sklearn.impute import KNNImputer

# %%
imputer = KNNImputer(n_neighbors=30)

# %% [markdown]
# Cabin has more than 60% missing values so cabin variable is dropped.Also object type variables dropped for knn imputation

# %%
train2 = train
train2.pop("Name")
train2.pop("Cabin")

# %%
train2.pop("Ticket")

# %%
train2.head()

# %%
train2 = pd.DataFrame(imputer.fit_transform(train2),columns = train2.columns)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
train2.pop("PassengerId")

# %%
categ = ["Sex","Embarked"]

# %%
train2 = pd.get_dummies(train2, columns = categ)

# %%
train2.head()

# %%
from sklearn.model_selection import train_test_split

# %%
variables=train2.drop(['Survived'], axis = "columns")
train_80var, train_20var, train_80far, train_20far = train_test_split(variables, train2['Survived'], test_size=.20, random_state=0)

# %%
train2.info()

# %%
model_rf = RandomForestClassifier(n_estimators=500).fit(train_80var,train_80far)

# %%
predict_rf = model_rf.predict(train_20var)

# %%
predict_rf

# %%
result = confusion_matrix(train_20far, predict_rf)
print("Confusion Matrix:")
print(result)
result1 = classification_report(train_20far, predict_rf)
print("Classification Report:",)
print (result1)
result2 = accuracy_score(train_20far,predict_rf)
print("Accuracy:",result2)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
MAPE_RF = np.mean(np.abs(predict_rf-train_20far))

# %%
MAPE_RF

# %%
import statsmodels.api as lr

# %%
model_lr= lr.OLS(train_80far,train_80var).fit()

# %%
predict_lr = model_lr.predict(train_20var)

# %%
MAPE_LR = np.mean(np.abs(predict_lr-train_20far))

# %%
MAPE_LR

# %% [markdown]
# Random Forest Method gives more accuracy

# %%
train2.shape

# %%
train3 = train2.drop(['Survived'], axis = "columns")

# %%
model_rf1=RandomForestClassifier(n_estimators=500).fit(train3,train2["Survived"])

# %%
test= test.drop(['Name','Cabin','Ticket','PassengerId'], axis = "columns")

# %%
test["Sex"] = test["Sex"].astype('category')

# %%
test["Sex"]=test.Sex.cat.codes

# %%
test["Embarked"] = test["Embarked"].astype('category')

# %%
test["Embarked"]=test.Embarked.cat.codes

# %%
imputer1 = KNNImputer(n_neighbors=20)

# %%
test = pd.DataFrame(imputer1.fit_transform(test),columns = test.columns)

# %%
test.info()

# %%
test = pd.get_dummies(test, columns = categ)

# %%
test["Embarked_-1.0"]=0

# %%
test.head()

# %%
train2.head()

# %%
predict_rf1 = model_rf1.predict(test)

# %%
df = pd.DataFrame({'PassengerId':test2['PassengerId'], 'Survived':predict_rf1})

# %%
df.to_csv('prediction_titanic1.csv')
